# %%
# !pip install azure-storage-blob
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: azure-storage-blob in /Users/karmayangchentenzin/Library/Python/3.9/lib/python/site-packages (12.19.1)
# Requirement already satisfied: azure-core<2.0.0,>=1.28.0 in /Users/karmayangchentenzin/Library/Python/3.9/lib/python/site-packages (from azure-storage-blob) (1.30.1)
# Requirement already satisfied: cryptography>=2.1.4 in /Users/karmayangchentenzin/Library/Python/3.9/lib/python/site-packages (from azure-storage-blob) (42.0.5)
# Requirement already satisfied: typing-extensions>=4.3.0 in /Users/karmayangchentenzin/Library/Python/3.9/lib/python/site-packages (from azure-storage-blob) (4.11.0)
# Requirement already satisfied: isodate>=0.6.1 in /Users/karmayangchentenzin/Library/Python/3.9/lib/python/site-packages (from azure-storage-blob) (0.6.1)
# Requirement already satisfied: requests>=2.21.0 in /Users/karmayangchentenzin/Library/Python/3.9/lib/python/site-packages (from azure-core<2.0.0,>=1.28.0->azure-storage-blob) (2.31.0)
# Requirement already satisfied: six>=1.11.0 in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from azure-core<2.0.0,>=1.28.0->azure-storage-blob) (1.15.0)
# Requirement already satisfied: cffi>=1.12 in /Users/karmayangchentenzin/Library/Python/3.9/lib/python/site-packages (from cryptography>=2.1.4->azure-storage-blob) (1.16.0)
# Requirement already satisfied: pycparser in /Users/karmayangchentenzin/Library/Python/3.9/lib/python/site-packages (from cffi>=1.12->cryptography>=2.1.4->azure-storage-blob) (2.22)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/karmayangchentenzin/Library/Python/3.9/lib/python/site-packages (from requests>=2.21.0->azure-core<2.0.0,>=1.28.0->azure-storage-blob) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/karmayangchentenzin/Library/Python/3.9/lib/python/site-packages (from requests>=2.21.0->azure-core<2.0.0,>=1.28.0->azure-storage-blob) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/karmayangchentenzin/Library/Python/3.9/lib/python/site-packages (from requests>=2.21.0->azure-core<2.0.0,>=1.28.0->azure-storage-blob) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/karmayangchentenzin/Library/Python/3.9/lib/python/site-packages (from requests>=2.21.0->azure-core<2.0.0,>=1.28.0->azure-storage-blob) (2024.2.2)

# %%
import pandas as pd
import numpy as np
import json
import requests
from io import StringIO
from azure.storage.blob import BlobServiceClient, BlobClient, ContainerClient
import os
from math import ceil
import datetime
import calendar

# %%
# Specify the file path in system
file_path = r'/Users/karmayangchentenzin/Downloads/otc_data.csv'

# %%
import os

# Get the directory of the current notebook/script
notebook_dir = os.getcwd()

# Construct the path to the config.json file
config_file_path = os.path.join(notebook_dir, 'config.json')

# Load the JSON configuration file
try:
    with open(config_file_path, 'r') as config_file:
        config = json.load(config_file)
    # Access configuration values as needed
    CONNECTION_STRING_AZURE_STORAGE = config["connectionString"]
    container_name = "otcgroup6"
    blob_name = "otc"
    # Continue with your code
except FileNotFoundError:
    print(f"Config file not found at path: {config_file_path}")
except json.JSONDecodeError as e:
    print("Error decoding JSON:", e)


with open(config_file_path, 'r') as config_file:
    file_contents = config_file.read()
    print("File Contents:", file_contents)
# Out:
# File Contents: {
#     "connectionString": "DefaultEndpointsProtocol=https;AccountName=cis4400group6project;AccountKey=NnFE78e1rGBmg6R+nMNaE/9zd63opn/UmjJe4tNUuZY1LMyZ47GpO3UfX27ky5Wd2qKA6aJz+wbj+AStF95sKQ==;EndpointSuffix=core.windows.net"
# }

# %%
# Specify the path to your JSON configuration file
config_file_path = 'config.json'

# Load the JSON configuration file
with open(config_file_path, 'r') as config_file:
    config = json.load(config_file)

# Azure Storage connection string and container name
CONNECTION_STRING_AZURE_STORAGE = config["connectionString"]
container_name = "otcgroup6"
blob_name = "otc"

# Initialize BlobServiceClient
blob_service_client = BlobServiceClient.from_connection_string(CONNECTION_STRING_AZURE_STORAGE)

# Create a blob client using the container name and blob name
#container_client = blob_service_client.get_container_client(CONTAINER_AZURE)
blob_client = blob_service_client.get_blob_client(container=container_name, blob=os.path.basename(file_path))

# Upload the csv file to Azure Blob Storage
with open(file_path, "rb") as data:
    blob_client.upload_blob(data)

print(f"Uploaded {blob_name} to Azure Blob Storage in container {container_name}")
# Out:
# ---------------------------------------------------------------------------
# ServiceResponseError                      Traceback (most recent call last)
# Cell In[24], line 22
#      20 # Upload the csv file to Azure Blob Storage
#      21 with open(file_path, "rb") as data:
# ---> 22     blob_client.upload_blob(data)
#      24 print(f"Uploaded {blob_name} to Azure Blob Storage in container {container_name}")
#
# File ~/Library/Python/3.9/lib/python/site-packages/azure/core/tracing/decorator.py:78, in distributed_trace.<locals>.decorator.<locals>.wrapper_use_tracer(*args, **kwargs)
#      76 span_impl_type = settings.tracing_implementation()
#      77 if span_impl_type is None:
# ---> 78     return func(*args, **kwargs)
#      80 # Merge span is parameter is set, but only if no explicit parent are passed
#      81 if merge_span and not passed_in_parent:
#
# File ~/Library/Python/3.9/lib/python/site-packages/azure/storage/blob/_blob_client.py:765, in BlobClient.upload_blob(self, data, blob_type, length, metadata, **kwargs)
#     758 options = self._upload_blob_options(
#     759     data,
#     760     blob_type=blob_type,
#     761     length=length,
#     762     metadata=metadata,
#     763     **kwargs)
#     764 if blob_type == BlobType.BlockBlob:
# --> 765     return upload_block_blob(**options)
#     766 if blob_type == BlobType.PageBlob:
#     767     return upload_page_blob(**options)
#
# File ~/Library/Python/3.9/lib/python/site-packages/azure/storage/blob/_upload_helpers.py:151, in upload_block_blob(client, data, stream, length, overwrite, headers, validate_content, max_concurrency, blob_settings, encryption_options, **kwargs)
#     148             # V2 wraps the data stream with an encryption stream
#     149             stream = GCMBlobEncryptionStream(cek, stream)
# --> 151     block_ids = upload_data_chunks(
#     152         service=client,
#     153         uploader_class=BlockBlobChunkUploader,
#     154         total_size=total_size,
#     155         chunk_size=blob_settings.max_block_size,
#     156         max_concurrency=max_concurrency,
#     157         stream=stream,
#     158         validate_content=validate_content,
#     159         progress_hook=progress_hook,
#     160         encryptor=encryptor,
#     161         padder=padder,
#     162         headers=headers,
#     163         **kwargs
#     164     )
#     165 else:
#     166     block_ids = upload_substream_blocks(
#     167         service=client,
#     168         uploader_class=BlockBlobChunkUploader,
#    (...)
#     176         **kwargs
#     177     )
#
# File ~/Library/Python/3.9/lib/python/site-packages/azure/storage/blob/_shared/uploads.py:77, in upload_data_chunks(service, uploader_class, total_size, chunk_size, max_concurrency, stream, validate_content, progress_hook, **kwargs)
#      75         range_ids = _parallel_uploads(executor, uploader.process_chunk, upload_tasks, running_futures)
#      76 else:
# ---> 77     range_ids = [uploader.process_chunk(result) for result in uploader.get_chunk_streams()]
#      78 if any(range_ids):
#      79     return [r[1] for r in sorted(range_ids, key=lambda r: r[0])]
#
# File ~/Library/Python/3.9/lib/python/site-packages/azure/storage/blob/_shared/uploads.py:77, in <listcomp>(.0)
#      75         range_ids = _parallel_uploads(executor, uploader.process_chunk, upload_tasks, running_futures)
#      76 else:
# ---> 77     range_ids = [uploader.process_chunk(result) for result in uploader.get_chunk_streams()]
#      78 if any(range_ids):
#      79     return [r[1] for r in sorted(range_ids, key=lambda r: r[0])]
#
# File ~/Library/Python/3.9/lib/python/site-packages/azure/storage/blob/_shared/uploads.py:193, in _ChunkUploader.process_chunk(self, chunk_data)
#     191 chunk_bytes = chunk_data[1]
#     192 chunk_offset = chunk_data[0]
# --> 193 return self._upload_chunk_with_progress(chunk_offset, chunk_bytes)
#
# File ~/Library/Python/3.9/lib/python/site-packages/azure/storage/blob/_shared/uploads.py:209, in _ChunkUploader._upload_chunk_with_progress(self, chunk_offset, chunk_data)
#     208 def _upload_chunk_with_progress(self, chunk_offset, chunk_data):
# --> 209     range_id = self._upload_chunk(chunk_offset, chunk_data)
#     210     self._update_progress(len(chunk_data))
#     211     return range_id
#
# File ~/Library/Python/3.9/lib/python/site-packages/azure/storage/blob/_shared/uploads.py:258, in BlockBlobChunkUploader._upload_chunk(self, chunk_offset, chunk_data)
#     256 index = f'{chunk_offset:032d}'
#     257 block_id = encode_base64(url_quote(encode_base64(index)))
# --> 258 self.service.stage_block(
#     259     block_id,
#     260     len(chunk_data),
#     261     chunk_data,
#     262     data_stream_total=self.total_size,
#     263     upload_stream_current=self.progress_total,
#     264     **self.request_options
#     265 )
#     266 return index, block_id
#
# File ~/Library/Python/3.9/lib/python/site-packages/azure/core/tracing/decorator.py:78, in distributed_trace.<locals>.decorator.<locals>.wrapper_use_tracer(*args, **kwargs)
#      76 span_impl_type = settings.tracing_implementation()
#      77 if span_impl_type is None:
# ---> 78     return func(*args, **kwargs)
#      80 # Merge span is parameter is set, but only if no explicit parent are passed
#      81 if merge_span and not passed_in_parent:
#
# File ~/Library/Python/3.9/lib/python/site-packages/azure/storage/blob/_generated/operations/_block_blob_operations.py:1246, in BlockBlobOperations.stage_block(self, block_id, content_length, body, transactional_content_md5, transactional_content_crc64, timeout, request_id_parameter, lease_access_conditions, cpk_info, cpk_scope_info, **kwargs)
#    1243 request.url = self._client.format_url(request.url)
#    1245 _stream = False
# -> 1246 pipeline_response: PipelineResponse = self._client._pipeline.run(  # pylint: disable=protected-access
#    1247     request, stream=_stream, **kwargs
#    1248 )
#    1250 response = pipeline_response.http_response
#    1252 if response.status_code not in [201]:
#
# File ~/Library/Python/3.9/lib/python/site-packages/azure/core/pipeline/_base.py:230, in Pipeline.run(self, request, **kwargs)
#     228 pipeline_request: PipelineRequest[HTTPRequestType] = PipelineRequest(request, context)
#     229 first_node = self._impl_policies[0] if self._impl_policies else _TransportRunner(self._transport)
# --> 230 return first_node.send(pipeline_request)
#
# File ~/Library/Python/3.9/lib/python/site-packages/azure/core/pipeline/_base.py:86, in _SansIOHTTPPolicyRunner.send(self, request)
#      84 _await_result(self._policy.on_request, request)
#      85 try:
# ---> 86     response = self.next.send(request)
#      87 except Exception:  # pylint: disable=broad-except
#      88     _await_result(self._policy.on_exception, request)
#
# File ~/Library/Python/3.9/lib/python/site-packages/azure/core/pipeline/_base.py:86, in _SansIOHTTPPolicyRunner.send(self, request)
#      84 _await_result(self._policy.on_request, request)
#      85 try:
# ---> 86     response = self.next.send(request)
#      87 except Exception:  # pylint: disable=broad-except
#      88     _await_result(self._policy.on_exception, request)
#
#     [... skipping similar frames: _SansIOHTTPPolicyRunner.send at line 86 (2 times)]
#
# File ~/Library/Python/3.9/lib/python/site-packages/azure/core/pipeline/_base.py:86, in _SansIOHTTPPolicyRunner.send(self, request)
#      84 _await_result(self._policy.on_request, request)
#      85 try:
# ---> 86     response = self.next.send(request)
#      87 except Exception:  # pylint: disable=broad-except
#      88     _await_result(self._policy.on_exception, request)
#
# File ~/Library/Python/3.9/lib/python/site-packages/azure/core/pipeline/policies/_redirect.py:197, in RedirectPolicy.send(self, request)
#     195 original_domain = get_domain(request.http_request.url) if redirect_settings["allow"] else None
#     196 while retryable:
# --> 197     response = self.next.send(request)
#     198     redirect_location = self.get_redirect_location(response)
#     199     if redirect_location and redirect_settings["allow"]:
#
# File ~/Library/Python/3.9/lib/python/site-packages/azure/core/pipeline/_base.py:86, in _SansIOHTTPPolicyRunner.send(self, request)
#      84 _await_result(self._policy.on_request, request)
#      85 try:
# ---> 86     response = self.next.send(request)
#      87 except Exception:  # pylint: disable=broad-except
#      88     _await_result(self._policy.on_exception, request)
#
# File ~/Library/Python/3.9/lib/python/site-packages/azure/storage/blob/_shared/policies.py:549, in StorageRetryPolicy.send(self, request)
#     547             self.sleep(retry_settings, request.context.transport)
#     548             continue
# --> 549         raise err
#     550 if retry_settings['history']:
#     551     response.context['history'] = retry_settings['history']
#
# File ~/Library/Python/3.9/lib/python/site-packages/azure/storage/blob/_shared/policies.py:523, in StorageRetryPolicy.send(self, request)
#     521 while retries_remaining:
#     522     try:
# --> 523         response = self.next.send(request)
#     524         if is_retry(response, retry_settings['mode']):
#     525             retries_remaining = self.increment(
#     526                 retry_settings,
#     527                 request=request.http_request,
#     528                 response=response.http_response)
#
# File ~/Library/Python/3.9/lib/python/site-packages/azure/core/pipeline/_base.py:86, in _SansIOHTTPPolicyRunner.send(self, request)
#      84 _await_result(self._policy.on_request, request)
#      85 try:
# ---> 86     response = self.next.send(request)
#      87 except Exception:  # pylint: disable=broad-except
#      88     _await_result(self._policy.on_exception, request)
#
# File ~/Library/Python/3.9/lib/python/site-packages/azure/core/pipeline/_base.py:86, in _SansIOHTTPPolicyRunner.send(self, request)
#      84 _await_result(self._policy.on_request, request)
#      85 try:
# ---> 86     response = self.next.send(request)
#      87 except Exception:  # pylint: disable=broad-except
#      88     _await_result(self._policy.on_exception, request)
#
#     [... skipping similar frames: _SansIOHTTPPolicyRunner.send at line 86 (1 times)]
#
# File ~/Library/Python/3.9/lib/python/site-packages/azure/core/pipeline/_base.py:86, in _SansIOHTTPPolicyRunner.send(self, request)
#      84 _await_result(self._policy.on_request, request)
#      85 try:
# ---> 86     response = self.next.send(request)
#      87 except Exception:  # pylint: disable=broad-except
#      88     _await_result(self._policy.on_exception, request)
#
# File ~/Library/Python/3.9/lib/python/site-packages/azure/storage/blob/_shared/policies.py:312, in StorageResponseHook.send(self, request)
#     307     upload_stream_current = request.context.options.pop('upload_stream_current', None)
#     309 response_callback = request.context.get('response_callback') or \
#     310     request.context.options.pop('raw_response_hook', self._response_callback)
# --> 312 response = self.next.send(request)
#     314 will_retry = is_retry(response, request.context.options.get('mode'))
#     315 # Auth error could come from Bearer challenge, in which case this request will be made again
#
# File ~/Library/Python/3.9/lib/python/site-packages/azure/core/pipeline/_base.py:86, in _SansIOHTTPPolicyRunner.send(self, request)
#      84 _await_result(self._policy.on_request, request)
#      85 try:
# ---> 86     response = self.next.send(request)
#      87 except Exception:  # pylint: disable=broad-except
#      88     _await_result(self._policy.on_exception, request)
#
# File ~/Library/Python/3.9/lib/python/site-packages/azure/core/pipeline/_base.py:86, in _SansIOHTTPPolicyRunner.send(self, request)
#      84 _await_result(self._policy.on_request, request)
#      85 try:
# ---> 86     response = self.next.send(request)
#      87 except Exception:  # pylint: disable=broad-except
#      88     _await_result(self._policy.on_exception, request)
#
# File ~/Library/Python/3.9/lib/python/site-packages/azure/core/pipeline/_base.py:119, in _TransportRunner.send(self, request)
#     109 """HTTP transport send method.
#     110
#     111 :param request: The PipelineRequest object.
#    (...)
#     114 :rtype: ~azure.core.pipeline.PipelineResponse
#     115 """
#     116 cleanup_kwargs_for_transport(request.context.options)
#     117 return PipelineResponse(
#     118     request.http_request,
# --> 119     self._sender.send(request.http_request, **request.context.options),
#     120     context=request.context,
#     121 )
#
# File ~/Library/Python/3.9/lib/python/site-packages/azure/storage/blob/_shared/base_client.py:336, in TransportWrapper.send(self, request, **kwargs)
#     335 def send(self, request, **kwargs):
# --> 336     return self._transport.send(request, **kwargs)
#
# File ~/Library/Python/3.9/lib/python/site-packages/azure/core/pipeline/transport/_requests_basic.py:386, in RequestsTransport.send(self, request, proxies, **kwargs)
#     383     error = ServiceRequestError(err, error=err)
#     385 if error:
# --> 386     raise error
#     387 if _is_rest(request):
#     388     from azure.core.rest._requests_basic import RestRequestsTransportResponse
#
# ServiceResponseError: ('Connection aborted.', timeout('The write operation timed out'))
